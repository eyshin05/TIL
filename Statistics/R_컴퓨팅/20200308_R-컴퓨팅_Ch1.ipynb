# %%
# 연구과제 1

help(faithful)

# %%
dim(faithful)
# Out:
# [1] 272   2

# %%
summary(faithful)
# Out:
#    eruptions        waiting
#  Min.   :1.600   Min.   :43.0
#  1st Qu.:2.163   1st Qu.:58.0
#  Median :4.000   Median :76.0
#  Mean   :3.488   Mean   :70.9
#  3rd Qu.:4.454   3rd Qu.:82.0
#  Max.   :5.100   Max.   :96.0

# %%
plot(faithful)
# Out:
# plot without title

# %%
# 연구과제 3

#install.packages("lars")
# Out:
# The downloaded binary packages are in
# 	/var/folders/8b/d2rf1xf10wx9hxjzfk1b49y40000gn/T//Rtmpv0d1pR/downloaded_packages

# %%
library("lars")
help("cv.lars")
# Out:
# Loaded lars 1.2
